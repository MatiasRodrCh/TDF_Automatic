# %%
import os
import pandas as pd
import os
import gspread
import datetime

# %%
def unzipTDF(fileName):
    import zipfile
    
    print("Descomprimiendo archivo ...")
    with zipfile.ZipFile(fileName,"r") as zip_ref:
        zip_ref.extractall()

    # Specify the path of the file to be deleted
    file_path = fileName
    # Check if the file exists before attempting to delete it
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f"The file {file_path} has been deleted.")
    else:
        print(f"The file {file_path} does not exist.")
    filenNameXLS = fileName[0:fileName.index(".")]
    filenNameXLS = filenNameXLS + ".xls"        
    return filenNameXLS

# %%
def getTDF():
    import imaplib
    import email

    user = 'mrodriguezcheroky'
    password = 'ozyl qbah amca yvot'
    server = imaplib.IMAP4_SSL('imap.gmail.com')
    server.login(user, password)
    server.select('TDF')

    fileName = ''
    detach_dir = '.'
    #if 'attachments' not in os.listdir(detach_dir):
    #    os.mkdir('attachments')

    print("Iniciando proceso de recupercion de mail ...")
        
    typ, data = server.search(None, 'UNSEEN SUBJECT "TDF"')
    if data[0]:
        for msgId in data[0].split():
            typ, messageParts = server.fetch(msgId, '(RFC822)')
            emailBody = messageParts[0][1]
            raw_email_string = emailBody.decode('utf-8')
            mail = email.message_from_string(raw_email_string)#
            print('emailbody complete ...')
            for part in mail.walk():
                if part.get_content_maintype() == 'multipart':
                    #print(part.as_string()) QUITAR?
                    continue
                if part.get('Content-Disposition') is None:
                    #print(part.as_string()) QUITAR?
                    continue
                fileName = part.get_filename()
                print('file names processed ...')
                if bool(fileName):
                    filePath = os.path.join(detach_dir, fileName)
                    if not os.path.isfile(filePath):
                        print("Archivo adjunto: ", fileName) # QUITAR?
                        fp = open(filePath, 'wb')
                        fp.write(part.get_payload(decode=True))
                        fp.close()
                        print('fp closed ...')
    server.close()
    server.logout()
    return fileName

# %%
def TDFtoGSheet(fileNameXLS, worksheet):

    print("Importando datos a Google Sheets ...")
    datos_excel = pd.read_html(fileNameXLS)[0]
    datos_excel.columns = datos_excel.iloc[0]
    datos_excel = datos_excel.drop(0)

    file_path = fileNameXLS
    # Check if the file exists before attempting to delete it
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f"The file {file_path} has been deleted.")
    else:
        print(f"The file {file_path} does not exist.")

    for i, col in enumerate(datos_excel.columns):
        if i == 0 :
            continue
        else :
            datos_excel[col] = datos_excel[col].map(int)
    worksheet.clear()
    worksheet.update([datos_excel.columns.values.tolist()] + datos_excel.values.tolist())
    return datos_excel

# %%
def getGSheet(googleSheetId):
    from oauth2client.service_account import ServiceAccountCredentials

    # Define the scope
    scope = ['https://spreadsheets.google.com/feeds',
            'https://www.googleapis.com/auth/spreadsheets',
            'https://www.googleapis.com/auth/drive.file',
            'https://www.googleapis.com/auth/drive']

    # Define the credentials file path
    creds = ServiceAccountCredentials.from_json_keyfile_name('key.json', scope)

    # Authorize the client
    client = gspread.authorize(creds)

    # Open the spreadsheet
    gsheet = client.open_by_key(googleSheetId)
    return gsheet

# %%
fileName = getTDF()
if fileName :
    filenNameXLS = unzipTDF(fileName)
    gs = getGSheet("16XHtpBjy0jSb8QfHwkRJy86-4h3wNv_YeiQygxYp-R4")
    df = TDFtoGSheet(filenNameXLS, gs.worksheet("TDF"))

    ws = gs.worksheet("SaldosATMs")
    fechaHoraActual = datetime.datetime.now()
    cadena_formato = "%d/%m/%Y %H:%M:%S"
    fecha_hora_str = fechaHoraActual.strftime(cadena_formato)
    ws.update_cell(1, 3, fecha_hora_str)

    print("Registros insertados!!")
else:
    print("No hay TDF disponible")
# Out:
# Iniciando proceso de recupercion de mail ...
# emailbody complete ...
# file names processed ...
# Archivo adjunto:  BM_positdf_13jun21hs.zip
# fp closed ...
# Descomprimiendo archivo ...
# The file BM_positdf_13jun21hs.zip has been deleted.
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# Cell In[7], line 4
#       2 if fileName :
#       3     filenNameXLS = unzipTDF(fileName)
# ----> 4     gs = getGSheet("16XHtpBjy0jSb8QfHwkRJy86-4h3wNv_YeiQygxYp-R4")
#       5     df = TDFtoGSheet(filenNameXLS, gs.worksheet("TDF"))
#       7     ws = gs.worksheet("SaldosATMs")
#
# Cell In[4], line 17, in getGSheet(googleSheetId)
#      14 client = gspread.authorize(creds)
#      16 # Open the spreadsheet
# ---> 17 gsheet = client.open_by_key(googleSheetId)
#      18 return gsheet
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\gspread\client.py:155, in Client.open_by_key(self, key)
#     147 """Opens a spreadsheet specified by `key` (a.k.a Spreadsheet ID).
#     148
#     149 :param str key: A key of a spreadsheet as it appears in a URL in a browser.
#    (...)
#     152 >>> gc.open_by_key('0BmgG6nO_6dprdS1MN3d3MkdPa142WFRrdnRRUWl1UFE')
#     153 """
#     154 try:
# --> 155     spreadsheet = Spreadsheet(self.http_client, {"id": key})
#     156 except APIError as ex:
#     157     if ex.response.status_code == HTTPStatus.NOT_FOUND:
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\gspread\spreadsheet.py:29, in Spreadsheet.__init__(self, http_client, properties)
#      26 self.client = http_client
#      27 self._properties = properties
# ---> 29 metadata = self.fetch_sheet_metadata()
#      30 self._properties.update(metadata["properties"])
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\gspread\spreadsheet.py:230, in Spreadsheet.fetch_sheet_metadata(self, params)
#     218 def fetch_sheet_metadata(
#     219     self, params: Optional[ParamsType] = None
#     220 ) -> Mapping[str, Any]:
#     221     """Similar to :method spreadsheets_get:`gspread.http_client.spreadsheets_get`,
#     222     get the spreadsheet form the API but by default **does not get the cells data**.
#     223     It only retrieve the the metadata from the spreadsheet.
#    (...)
#     228     :rtype: dict
#     229     """
# --> 230     return self.client.fetch_sheet_metadata(self.id, params=params)
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\gspread\http_client.py:305, in HTTPClient.fetch_sheet_metadata(self, id, params)
#     301     params = {"includeGridData": "false"}
#     303 url = SPREADSHEET_URL % id
# --> 305 r = self.request("get", url, params=params)
#     307 return r.json()
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\gspread\http_client.py:114, in HTTPClient.request(self, method, endpoint, params, data, json, files, headers)
#     104 def request(
#     105     self,
#     106     method: str,
#    (...)
#     112     headers: Optional[MutableMapping[str, str]] = None,
#     113 ) -> Response:
# --> 114     response = self.session.request(
#     115         method=method,
#     116         url=endpoint,
#     117         json=json,
#     118         params=params,
#     119         data=data,
#     120         files=files,
#     121         headers=headers,
#     122         timeout=self.timeout,
#     123     )
#     125     if response.ok:
#     126         return response
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\google\auth\transport\requests.py:534, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     531 remaining_time = max_allowed_time
#     533 with TimeoutGuard(remaining_time) as guard:
# --> 534     self.credentials.before_request(auth_request, method, url, request_headers)
#     535 remaining_time = guard.remaining_timeout
#     537 with TimeoutGuard(remaining_time) as guard:
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\google\auth\credentials.py:230, in Credentials.before_request(self, request, method, url, headers)
#     228     self._non_blocking_refresh(request)
#     229 else:
# --> 230     self._blocking_refresh(request)
#     232 metrics.add_metric_header(headers, self._metric_header_for_usage())
#     233 self.apply(headers)
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\google\auth\credentials.py:193, in Credentials._blocking_refresh(self, request)
#     191 def _blocking_refresh(self, request):
#     192     if not self.valid:
# --> 193         self.refresh(request)
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\google\oauth2\service_account.py:446, in Credentials.refresh(self, request)
#     444 else:
#     445     assertion = self._make_authorization_grant_assertion()
# --> 446     access_token, expiry, _ = _client.jwt_grant(
#     447         request, self._token_uri, assertion
#     448     )
#     449     self.token = access_token
#     450     self.expiry = expiry
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\google\oauth2\_client.py:304, in jwt_grant(request, token_uri, assertion, can_retry)
#     280 """Implements the JWT Profile for OAuth 2.0 Authorization Grants.
#     281
#     282 For more details, see `rfc7523 section 4`_.
#    (...)
#     300 .. _rfc7523 section 4: https://tools.ietf.org/html/rfc7523#section-4
#     301 """
#     302 body = {"assertion": assertion, "grant_type": _JWT_GRANT_TYPE}
# --> 304 response_data = _token_endpoint_request(
#     305     request,
#     306     token_uri,
#     307     body,
#     308     can_retry=can_retry,
#     309     headers={
#     310         metrics.API_CLIENT_HEADER: metrics.token_request_access_token_sa_assertion()
#     311     },
#     312 )
#     314 try:
#     315     access_token = response_data["access_token"]
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\google\oauth2\_client.py:275, in _token_endpoint_request(request, token_uri, body, access_token, use_json, can_retry, headers, **kwargs)
#     264 response_status_ok, response_data, retryable_error = _token_endpoint_request_no_throw(
#     265     request,
#     266     token_uri,
#    (...)
#     272     **kwargs
#     273 )
#     274 if not response_status_ok:
# --> 275     _handle_error_response(response_data, retryable_error)
#     276 return response_data
#
# File c:\Users\fisu\anaconda3\Lib\site-packages\google\oauth2\_client.py:68, in _handle_error_response(response_data, retryable_error)
#      65 except (KeyError, ValueError):
#      66     error_details = json.dumps(response_data)
# ---> 68 raise exceptions.RefreshError(
#      69     error_details, response_data, retryable=retryable_error
#      70 )
#
# RefreshError: ('invalid_grant: Invalid JWT Signature.', {'error': 'invalid_grant', 'error_description': 'Invalid JWT Signature.'})
